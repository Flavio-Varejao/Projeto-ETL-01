# %% [markdown]
# # Etapa 2 - Limpeza dos Dados

# %%
import pandas as pd
import pandera as pa

# %%
#Criação do dataframe e checagem dos dados
df = pd.read_csv("93f4e8c2-430f-4142-86b3-96dab4905b4e.csv", parse_dates=['data_inicio_primeiros_sintomas','data_notificacao','data_obito'])
df.head(10)
# Out:
#    _id       sexo    idade      raca  etnia  \
# 0    1  Masculino  9 meses  Ignorado    NaN
# 1    2   Feminino       46    Branca    NaN
# 2    3  Masculino       78    Branca    NaN
# 3    4   Feminino       62     Parda    NaN
# 4    5  Masculino       26     Parda    NaN
# 5    6  Masculino       39  Ignorado    NaN
# 6    7   Feminino        1  Ignorado    NaN
# 7    8   Feminino       34    Branca    NaN
# 8    9  Masculino       61  Ignorado    NaN
# 9   10  Masculino       59    Branca    NaN
#
#                                   morbidades_previas  \
# 0                     Doenças Respiratórias Crônicas
# 1                                                NaN
# 2  Doenças Cardíacas ou Vasculares, Doença Hepáti...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                Sobrepeso/Obesidade
# 8                                                NaN
# 9                                    Imunossupressão
#
#   outras_morbidades_previas                       evolucao  \
# 0                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 1                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 2                       NaN                          ÓBITO
# 3                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 4                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 6                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 7                       NaN                     RECUPERADO
# 8                       NaN                     RECUPERADO
# 9                       NaN                     RECUPERADO
#
#   data_inicio_primeiros_sintomas data_notificacao data_obito  \
# 0                     2021-02-24       2021-03-02        NaT
# 1                     2021-02-28       2021-03-03        NaT
# 2                     2021-01-06       2021-01-08 2021-01-26
# 3                     2021-02-23       2021-03-02        NaT
# 4                     2021-02-24       2021-03-01        NaT
# 5                     2021-02-18       2021-03-02        NaT
# 6                     2021-02-20       2021-02-28        NaT
# 7                     2021-01-12       2021-01-22        NaT
# 8                     2021-02-01       2021-02-12        NaT
# 9                     2021-01-22       2021-01-25        NaT
#
#   classificacao_final
# 0          DESCARTADO
# 1          EM ANÁLISE
# 2          CONFIRMADO
# 3          EM ANÁLISE
# 4          DESCARTADO
# 5          DESCARTADO
# 6          DESCARTADO
# 7          CONFIRMADO
# 8          CONFIRMADO
# 9          CONFIRMADO

# %%
#Verificação dos tipos de dados
df.dtypes
# Out:
# _id                                 int64
# sexo                               object
# idade                              object
# raca                               object
# etnia                             float64
# morbidades_previas                 object
# outras_morbidades_previas          object
# evolucao                           object
# data_inicio_primeiros_sintomas     object
# data_notificacao                   object
# data_obito                         object
# classificacao_final                object
# dtype: object

# %%
#Observações:

#A coluna 'idade' permanecerá como 'object' porque também aceita os meses como idade, conforme o dicionário da base de dados (casosgravescovid.json)

#A coluna 'etnia' será convertida para 'object', conforme o dicionário da base de dados (casosgravescovid.json)

#A coluna 'data_inicio_primeiros_sintomas' deveria ser do tipo datetime, conforme registrado no dicionário da
#base de dados (casosgravescovid.json), mas há inconsistências nas células preenchidas, como por exemplo uma data com 
#seguinte formato: '00/01/1900'. Logo, essas células serão tratadas na etapa de transformação.

#As colunas 'data_notificacao' e 'data_obito' serão convertidas para 'datetime', conforme o dicionário da base de dados (casosgravescovid.json)

# %%
#Inclusão do parâmetro 'parse_dates' no dataframe

# %%
df.dtypes
# Out:
# _id                                        int64
# sexo                                      object
# idade                                     object
# raca                                      object
# etnia                                    float64
# morbidades_previas                        object
# outras_morbidades_previas                 object
# evolucao                                  object
# data_inicio_primeiros_sintomas            object
# data_notificacao                  datetime64[ns]
# data_obito                        datetime64[ns]
# classificacao_final                       object
# dtype: object

# %%
#Validação dos dados

# %%
#O parâmetro 'nullable=True' foi adcionado em algumas colunas para validar os campos nulos

#As colunas 'etnia' e 'data_inicio_primeiros_sintomas' serão validadas mais adiante na etapa de limpeza

# %%
schema = pa.DataFrameSchema(
    columns = {
        "_id": pa.Column(pa.Int),
        "sexo": pa.Column(pa.String),
        "idade": pa.Column(pa.String),
        "raca": pa.Column(pa.String, nullable=True),
        #"etnia": pa.Column(pa.String),
        "morbidades_previas": pa.Column(pa.String, nullable=True),
        "outras_morbidades_previas": pa.Column(pa.String, nullable=True),
        "evolucao": pa.Column(pa.String, nullable=True),
        #"data_inicio_primeiros_sintomas": pa.Column(pa.DateTime),
        "data_notificacao": pa.Column(pa.DateTime),
        "data_obito": pa.Column(pa.DateTime, nullable=True),
        "classificacao_final": pa.Column(pa.String)
    }
)

# %%
schema.validate(df)
# Out:
#        _id       sexo    idade      raca  etnia  \
# 0        1  Masculino  9 meses  Ignorado    NaN
# 1        2   Feminino       46    Branca    NaN
# 2        3  Masculino       78    Branca    NaN
# 3        4   Feminino       62     Parda    NaN
# 4        5  Masculino       26     Parda    NaN
# ...    ...        ...      ...       ...    ...
# 5495  5496  Masculino  2 meses     Parda    NaN
# 5496  5497  Masculino       79     Parda    NaN
# 5497  5498  Masculino       79     Parda    NaN
# 5498  5499  Masculino       44     Parda    NaN
# 5499  5500  Masculino       58     Parda    NaN
#
#                                      morbidades_previas  \
# 0                        Doenças Respiratórias Crônicas
# 1                                                   NaN
# 2     Doenças Cardíacas ou Vasculares, Doença Hepáti...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5495                                                NaN
# 5496           Doenças Respiratórias Crônicas, Diabetes
# 5497                    Doenças Cardíacas ou Vasculares
# 5498  Doenças Cardíacas ou Vasculares, Sobrepeso/Obe...
# 5499                                                NaN
#
#      outras_morbidades_previas                       evolucao  \
# 0                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 1                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 2                          NaN                          ÓBITO
# 3                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 4                          NaN  INTERNADO LEITO DE ISOLAMENTO
# ...                        ...                            ...
# 5495                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5496              EX TABAGISTA                          ÓBITO
# 5497                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5498                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5499                       HAS                          ÓBITO
#
#      data_inicio_primeiros_sintomas data_notificacao data_obito  \
# 0                        2021-02-24       2021-03-02        NaT
# 1                        2021-02-28       2021-03-03        NaT
# 2                        2021-01-06       2021-01-08 2021-01-26
# 3                        2021-02-23       2021-03-02        NaT
# 4                        2021-02-24       2021-03-01        NaT
# ...                             ...              ...        ...
# 5495                     2020-10-31       2020-11-04        NaT
# 5496                     00/01/1900       2020-12-16 2020-11-19
# 5497                     2020-12-14       2020-12-17        NaT
# 5498                     2020-11-29       2020-12-01        NaT
# 5499                     2020-11-28       2020-12-02 2020-12-08
#
#      classificacao_final
# 0             DESCARTADO
# 1             EM ANÁLISE
# 2             CONFIRMADO
# 3             EM ANÁLISE
# 4             DESCARTADO
# ...                  ...
# 5495          DESCARTADO
# 5496          CONFIRMADO
# 5497          EM ANÁLISE
# 5498          DESCARTADO
# 5499          DESCARTADO
#
# [5500 rows x 12 columns]

# %%
#Renomear a coluna '_id' para 'id'
df = df.rename(columns={"_id":"id"})

# %%
df.head()
# Out:
#    id       sexo    idade      raca  etnia  \
# 0   1  Masculino  9 meses  Ignorado    NaN
# 1   2   Feminino       46    Branca    NaN
# 2   3  Masculino       78    Branca    NaN
# 3   4   Feminino       62     Parda    NaN
# 4   5  Masculino       26     Parda    NaN
#
#                                   morbidades_previas  \
# 0                     Doenças Respiratórias Crônicas
# 1                                                NaN
# 2  Doenças Cardíacas ou Vasculares, Doença Hepáti...
# 3                                                NaN
# 4                                                NaN
#
#   outras_morbidades_previas                       evolucao  \
# 0                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 1                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 2                       NaN                          ÓBITO
# 3                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 4                       NaN  INTERNADO LEITO DE ISOLAMENTO
#
#   data_inicio_primeiros_sintomas data_notificacao data_obito  \
# 0                     2021-02-24       2021-03-02        NaT
# 1                     2021-02-28       2021-03-03        NaT
# 2                     2021-01-06       2021-01-08 2021-01-26
# 3                     2021-02-23       2021-03-02        NaT
# 4                     2021-02-24       2021-03-01        NaT
#
#   classificacao_final
# 0          DESCARTADO
# 1          EM ANÁLISE
# 2          CONFIRMADO
# 3          EM ANÁLISE
# 4          DESCARTADO

# %%
#Localizando linhas com datas inconsistentes
df.loc[df.data_inicio_primeiros_sintomas == "00/01/1900"]
# Out:
#         id       sexo idade    raca  etnia  \
# 14      15   Feminino    93  Branca    NaN
# 57      58  Masculino    53   Parda    NaN
# 201    202   Feminino    18  Branca    NaN
# 416    417   Feminino    57   Parda    NaN
# 510    511  Masculino    11     NaN    NaN
# ...    ...        ...   ...     ...    ...
# 5255  5256   Feminino    41  Branca    NaN
# 5360  5361   Feminino    74   Preta    NaN
# 5386  5387  Masculino    80   Parda    NaN
# 5400  5401   Feminino    76   Parda    NaN
# 5496  5497  Masculino    79   Parda    NaN
#
#                                      morbidades_previas  \
# 14    Diabetes, Doenças Cardíacas ou Vasculares, Sob...
# 57                                                  NaN
# 201                                                 NaN
# 416                     Doenças Cardíacas ou Vasculares
# 510                                                 NaN
# ...                                                 ...
# 5255                                                NaN
# 5360                                                NaN
# 5386                                                NaN
# 5400                    Doenças Cardíacas ou Vasculares
# 5496           Doenças Respiratórias Crônicas, Diabetes
#
#                  outras_morbidades_previas                       evolucao  \
# 14                       NEOPLASIA DE PELE                          ÓBITO
# 57                                     NaN  INTERNADO LEITO DE ISOLAMENTO
# 201                               PUÉRPERA                            NaN
# 416                                    NaN                     RECUPERADO
# 510                                    NaN  INTERNADO LEITO DE ISOLAMENTO
# ...                                    ...                            ...
# 5255                                   NaN                            NaN
# 5360                                   NaN                          ÓBITO
# 5386                                   NaN                     RECUPERADO
# 5400  hipertensa e dpoc e efisema pulmonar                          ÓBITO
# 5496                          EX TABAGISTA                          ÓBITO
#
#      data_inicio_primeiros_sintomas data_notificacao data_obito  \
# 14                       00/01/1900       2021-01-07 2021-01-21
# 57                       00/01/1900       2020-06-30        NaT
# 201                      00/01/1900       2020-07-08        NaT
# 416                      00/01/1900       2021-03-30        NaT
# 510                      00/01/1900       2020-04-08        NaT
# ...                             ...              ...        ...
# 5255                     00/01/1900       2020-07-06        NaT
# 5360                     00/01/1900       2020-04-23 2020-04-29
# 5386                     00/01/1900       2020-05-28        NaT
# 5400                     00/01/1900       2020-12-21 2020-12-19
# 5496                     00/01/1900       2020-12-16 2020-11-19
#
#      classificacao_final
# 14            CONFIRMADO
# 57            DESCARTADO
# 201         INCONCLUSIVO
# 416           CONFIRMADO
# 510           DESCARTADO
# ...                  ...
# 5255        INCONCLUSIVO
# 5360          CONFIRMADO
# 5386          CONFIRMADO
# 5400          CONFIRMADO
# 5496          CONFIRMADO
#
# [195 rows x 12 columns]

# %%
#Visualização de todos os dados não informados por coluna (nulos)
df.isna().sum()
# Out:
# id                                   0
# sexo                                 0
# idade                                0
# raca                              1291
# etnia                             5500
# morbidades_previas                3689
# outras_morbidades_previas         4520
# evolucao                           157
# data_inicio_primeiros_sintomas       0
# data_notificacao                     0
# data_obito                        4231
# classificacao_final                  0
# dtype: int64

# %%
#Substituição de datas inconsistêntes para valor não informado
df.replace("00/01/1900", pd.NaT, inplace=True)

# %%
#Visualização de todos os dados não informados por coluna (nulos)
df.isna().sum()
# Out:
# id                                   0
# sexo                                 0
# idade                                0
# raca                              1291
# etnia                             5500
# morbidades_previas                3689
# outras_morbidades_previas         4520
# evolucao                           157
# data_inicio_primeiros_sintomas     195
# data_notificacao                     0
# data_obito                        4231
# classificacao_final                  0
# dtype: int64

# %%
#Alteração do tipo de dados da coluna 'data_inicio_primeiros_sintomas' para 'datetime'
df["data_inicio_primeiros_sintomas"] = df["data_inicio_primeiros_sintomas"].astype("datetime64")

# %%
#Alteração do tipo de dados da coluna 'etnia' para 'object'
df["etnia"] = df["etnia"].astype("object")

# %%
df.dtypes
# Out:
# id                                         int64
# sexo                                      object
# idade                                     object
# raca                                      object
# etnia                                     object
# morbidades_previas                        object
# outras_morbidades_previas                 object
# evolucao                                  object
# data_inicio_primeiros_sintomas    datetime64[ns]
# data_notificacao                  datetime64[ns]
# data_obito                        datetime64[ns]
# classificacao_final                       object
# dtype: object

# %%
#Validação dos dados

# %%
#O parâmetro 'nullable=True' foi adcionado nas colunas 'etnia' e 'data_inicio_primeiros_sintomas' para validar os campos nulos

# %%
schema = pa.DataFrameSchema(
    columns = {
        "id": pa.Column(pa.Int),
        "sexo": pa.Column(pa.String),
        "idade": pa.Column(pa.String),
        "raca": pa.Column(pa.String, nullable=True),
        "etnia": pa.Column(pa.String, nullable=True),
        "morbidades_previas": pa.Column(pa.String, nullable=True),
        "outras_morbidades_previas": pa.Column(pa.String, nullable=True),
        "evolucao": pa.Column(pa.String, nullable=True),
        "data_inicio_primeiros_sintomas": pa.Column(pa.DateTime, nullable=True),
        "data_notificacao": pa.Column(pa.DateTime),
        "data_obito": pa.Column(pa.DateTime, nullable=True),
        "classificacao_final": pa.Column(pa.String)
    }
)

# %%
schema.validate(df)
# Out:
#         id       sexo    idade      raca etnia  \
# 0        1  Masculino  9 meses  Ignorado   NaN
# 1        2   Feminino       46    Branca   NaN
# 2        3  Masculino       78    Branca   NaN
# 3        4   Feminino       62     Parda   NaN
# 4        5  Masculino       26     Parda   NaN
# ...    ...        ...      ...       ...   ...
# 5495  5496  Masculino  2 meses     Parda   NaN
# 5496  5497  Masculino       79     Parda   NaN
# 5497  5498  Masculino       79     Parda   NaN
# 5498  5499  Masculino       44     Parda   NaN
# 5499  5500  Masculino       58     Parda   NaN
#
#                                      morbidades_previas  \
# 0                        Doenças Respiratórias Crônicas
# 1                                                   NaN
# 2     Doenças Cardíacas ou Vasculares, Doença Hepáti...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5495                                                NaN
# 5496           Doenças Respiratórias Crônicas, Diabetes
# 5497                    Doenças Cardíacas ou Vasculares
# 5498  Doenças Cardíacas ou Vasculares, Sobrepeso/Obe...
# 5499                                                NaN
#
#      outras_morbidades_previas                       evolucao  \
# 0                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 1                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 2                          NaN                          ÓBITO
# 3                          NaN  INTERNADO LEITO DE ISOLAMENTO
# 4                          NaN  INTERNADO LEITO DE ISOLAMENTO
# ...                        ...                            ...
# 5495                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5496              EX TABAGISTA                          ÓBITO
# 5497                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5498                       NaN  INTERNADO LEITO DE ISOLAMENTO
# 5499                       HAS                          ÓBITO
#
#      data_inicio_primeiros_sintomas data_notificacao data_obito  \
# 0                        2021-02-24       2021-03-02        NaT
# 1                        2021-02-28       2021-03-03        NaT
# 2                        2021-01-06       2021-01-08 2021-01-26
# 3                        2021-02-23       2021-03-02        NaT
# 4                        2021-02-24       2021-03-01        NaT
# ...                             ...              ...        ...
# 5495                     2020-10-31       2020-11-04        NaT
# 5496                            NaT       2020-12-16 2020-11-19
# 5497                     2020-12-14       2020-12-17        NaT
# 5498                     2020-11-29       2020-12-01        NaT
# 5499                     2020-11-28       2020-12-02 2020-12-08
#
#      classificacao_final
# 0             DESCARTADO
# 1             EM ANÁLISE
# 2             CONFIRMADO
# 3             EM ANÁLISE
# 4             DESCARTADO
# ...                  ...
# 5495          DESCARTADO
# 5496          CONFIRMADO
# 5497          EM ANÁLISE
# 5498          DESCARTADO
# 5499          DESCARTADO
#
# [5500 rows x 12 columns]
